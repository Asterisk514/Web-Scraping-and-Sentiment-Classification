# %% [markdown]
# <a href="https://colab.research.google.com/github/Asterisk514/Web-Scraping-and-Sentiment-Classification/blob/main/Web_Scraping_and_Sentiment_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importing TextBlob for Classification ###

# %%
from textblob import TextBlob

# %% [markdown]
# ### Importing Required Modules ###

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### Fetching HTML Content using requests library ###

# %%
webpage = requests.get('https://www.livemint.com/market/stock-market-news').text

# %%
soup = BeautifulSoup(webpage, 'lxml')

# %%
soup.find_all('h2')[11].text.strip()
# Out:
# 'Nifty 50, Sensex hit fresh highs; auto stocks Maruti, M&M steal the show'

# %%
names = []
times = []
reading_time = []
urls = []

# %%
from urllib.parse import urljoin

# %% [markdown]
# ### Extracting information for 1st Webpage ###

# %%
base_url = "https://www.livemint.com/market/stock-market-news"

# %%
all_news = soup.find_all('div', class_ = "listingNew clearfix impression-candidate ga-tracking")
for news in all_news:
    the_news = news.find('div', class_ = "listtostory clearfix")
    headline_section = the_news.find('div', class_ = "headlineSec")
    headline = headline_section.find('h2').text.strip()
    names.append(headline)
    time = headline_section.find('span', attrs = {'data-updatedtime' : True}).get('data-updatedtime').strip()
    time_read = headline_section.find('span', class_ = "fl date").find('em').text
    reading_time.append(time_read)
    target_url = headline_section.find('h2', class_='headline').find('a')['href']
    stripped_target_url = target_url[len("/market/stock-market-news"):]
    final_link = urljoin(base_url, stripped_target_url)
    urls.append(final_link)
    times.append(time)

# %% [markdown]
# ### Extracting relevant information from each webpage ###

# %%
for idx in range(2, 10):
  webpage = requests.get(f'https://www.livemint.com/market/stock-market-news/page-{idx}').text
  base_url = f"https://www.livemint.com/market/stock-market-news/page-{idx}"
  soup = BeautifulSoup(webpage, 'lxml')
  all_news = soup.find_all('div', class_ = "listingNew clearfix impression-candidate ga-tracking")
  for news in all_news:
      the_news = news.find('div', class_ = "listtostory clearfix")
      headline_section = the_news.find('div', class_ = "headlineSec")
      headline = headline_section.find('h2').text.strip()
      names.append(headline)
      time = headline_section.find('span', attrs = {'data-updatedtime' : True}).get('data-updatedtime').strip()
      time_read = headline_section.find('span', class_ = "fl date").find('em').text
      reading_time.append(time_read)
      target_url = headline_section.find('h2', class_='headline').find('a')['href']
      stripped_target_url = target_url[len("/market/stock-market-news"):]
      final_link = urljoin(base_url, stripped_target_url)
      urls.append(final_link)
      times.append(time)

# %% [markdown]
# ### Extracted news headlines ###

# %%
for name in names:
  print(name)
# Out:
# Jerome Powell says more good data would strengthen case for rate cuts by Fed
# Budget 2024 | D-Street experts see heightened volatility ahead, suggest caution
# Stocks to buy: Heritage Foods, ONGC, among top four stock picks by SMC Global
# Voltas, Blue Star, Havells, others: Strong summer season sales to drive Q1 show
# Budget 2024 to focus on capex, Sensex eyes 90K by year-end: Subhash Aggarwal
# Kalpataru Projects rallied 265% in 25 months; should investors bet on the stock?
# Q1 earnings preview: These 4 companies may post over 40% jump in net profit
# Jupiter Wagon shares fall over 4% after board approves QIP launch
# Multibagger: Stylam Industries stock gained 110% in 16 months; what lies ahead?
# Sobha: After over 250% jump in the stock in a year, Geojit recommends ‘sell’
# Top Gainers and Losers today on 9 July, 2024: Maruti Suzuki India, Mahindra & Mahindra, Tata Consumer, Reliance Industries among most active stocks; Check full list here
# Nifty 50, Sensex hit fresh highs; auto stocks Maruti, M&M steal the show
# Small-cap stock below ₹10: Penny stock Sarveshwar Foods hits 5% upper circuit
# SEBI committee proposes stricter measures to curb derivatives volume surge
# Zomato share price rises over fivefold in 2 years. What should investors do now?
# Multibagger: Penny stock Kaushalya Infrastructure zooms 2537% in 5 years
# 6:1 bonus shares effect: ₹1.27 lakh turns to ₹11.81 lakh in three years
# Welspun Living share price surges over 7%
# RateGain Travel stock soars over 6% on Malaysia Airlines contract
# SMEs drive robust IPO activity in 2024 as 117 companies hit Dalal Street in H1
# AMFI rejig: Threshold for largecap increased to ₹84,300 crore
# Nifty logs highest monthly gain post-Lok Sabha polls. Explained with 5 reasons
# Multibagger stock Texmaco Rail slumps 6% on profit booking. Opportunity to buy?
# PC Jeweller zooms 10% for 2nd straight session, up 21% in 2 days; here's why
# Multibagger HEC Infra Projects share price hits 5% upper circuit on a order win
# Expert view: Budget 2024 unlikely to significantly impact any particular sector
# Maruti Suzuki shares surge 5% as UP frees hybrid vehicles from registration fees
# Stock to buy: Anand Rathi sees 20% upside for this multibagger PSU stock
# Jefferies surprised by India's resilience; says midcaps face greatest correction risk
# Multibagger stock hits lifetime high after Dolly Khanna's stake buying news
# Yes Bank clarifies on ‘stake sale’ report, calls it ‘factually incorrect’
# Affle India shares hit 52-week high after Citi assigns ‘Buy’; sees 17% upside
# Rice stocks, LT Foods, KRBL and LT Chaman Lal Setia Exports gain up to 14.5%
# Godrej Consumer shares fall over 2% after Q1 business update
# Inox Wind stocks surge after major announcement
# Nifty 50 may rise in short term; BHEL, CDSL among top technical picks Rupak De
# Mahanagar Gas share price rises 5% following CNG, PNG price hikes in Mumbai
# Stocks to buy or sell: Sumeet Bagadia recommends five breakout stocks
# Trade setup for stock market today: Five stocks to buy or sell on Tuesday
# Nifty 50, Sensex on July 9: What to expect in trade today
# Dollar droops before Powell testimony; euro weathers France uncertainty
# Indian stock market: 6 key things that changed for market overnight
# Buy or sell: Vaishali Parekh recommends three stocks to buy today — July 9
# Nifty Microcap 250 surged 11.56 % in June, Nifty 50 up 6.57%: Motilal Oswal
# US stocks edge higher ahead of key economic events, chip shares rally
# From BHEL to GAIL , Chandan Taparia suggests three stocks to buy today
# Nestle Dividend FY25: Stock surges over 2% on ₹2.75 interim dividend announcemen
# Hitachi Energy gains 235% in less than 9 months, climbs 1540% in 4 years
# Bajaj Auto, Hero, TVS: Steady 7-9% FY25 volume growth for two-wheeler- CareEdge
# TVS Motor to CONCOR—Vaishali Parekh suggests 3 stocks to buy, eyes 14% upside
# JSW Steel, IOC, Polycab, others to trade ex-dividend next week; Full list here
# Nvidia stock gets a rare downgrade post 154% returns, valuation concerns remain
# Radhika Gupta lists four factors that matter in your returns
# Weekend Wrap: From Solar to Yes Bank, top market movers and news of week
# SEBI conducting ‘surprise’ inspections; leading mutual funds under radar
# Buy or sell: Sumeet Bagadia recommends three stocks to buy on Monday
# Yes Bank share price jumps 11% on strong Q1 results buzz. Should you buy?
# Chinese, Indian stocks favoured over Japan in Asia’s second half
# Latam currencies set to log weekly gains as Fed rate cut bets firm
# Stock market today: Wall Street's record-setting rally rolls on as jobs data raises rate-cut hopes
# Efforts to secure Gaza ceasefire and hostage release gain momentum
# Efforts to secure Gaza ceasefire and hostage release gain momentum
# Wall Street Sees Dollar Regaining Strength After This Week’s Dip
# US labor market losing steam as unemployment rate climbs to 4.1%
# Fed rate cut debate to heat up as US job market cools
# Coal India, GSFC among top 10 firms paying high dividends; do you own any?
# Wall Street today: S&P 500, Nasdaq at record high on megacaps rally, yields drop
# Budget 2024: L&T to Oil India, D-Street expert suggests 4 stocks ahead of Budget
# Nifty 50 records longest weekly winning streak of 2024, ends at record high
# CONCOR and ideaForge are Anand Rathi’s 'emerging stock picks' for July 2024
# Top Gainers and Losers today on 5 July, 2024: Oil & Natural Gas Corporation, State Bank Of India, HDFC Bank, Titan Company among most active stocks; Check full list here
# Multibagger railway stocks RVNL, IRCON and 3 others surge up to 18%
# Sensex, Nifty 50 end flat dragged by HDFC Bank; mid, smallcaps outperform
# Budget 2024: What the stock market expects from the coalition government Budget
# L&T, ABB, BEL are 3 picks of MOFSL in capital goods space ahead of Q1 results
# IHCL: This Tata Group stock delivered 700% gain in 4 years
# Small-cap stock jumps 4% after HDFC Mutual Fund stake buying
# Why is Yes Bank share price skyrocketing today - explained
# BGR Energy Systems hits 5% upper circuit on ₹1,000 crore rights issue plan
# Expert view: Optimism overextended, consider reducing exposure to mid, smallcaps
# Financials, telecom, consumer services dominate FPI inflows in June
# Assessing Risks: A look at potential threats to India's market rally in H2FY24
# DMRC effect? RVNL share price hits lifetime high logging 9% intraday rise
# Ahluwalia Contracts shares jump 18% on ₹572 cr order win; up 624% in 4 years
# Ircon International hits 52-week high on ₹751-crore order win from RVNL
# Multibagger PSU stock HUDCO hits 52-week high. Should you buy?
# Tata Motors vs Tata Steel: Which Tata Group stock should you prefer in long term
# Remedium Lifecare share hits 20% upper circuit as stock trades ex-bonus today
# Mahindra Lifespace Developers stock soars 6% on ₹2050 crore real estate deals
# Stocks in focus: Rajesh Palviya of Axis Securities recommends three stocks today
# Iran holds runoff presidential vote pitting hard-liner against reformist after record low turnout
# HDFC Bank shares fall over 3% as deposits, advances growth decline in Q1
# Stocks to buy or sell: Sumeet Bagadia recommends five breakout stocks
# Trade setup for stock market today: Five stocks to buy or sell on Friday
# Nifty 50, Sensex on July 5: What to expect in trade today
# Indian stock market: 7 key things that changed for market overnight
# Buy or sell: Vaishali Parekh recommends three stocks to buy today — July 5
# British voters pick a new government against a backdrop of economic malaise and deep pessimism
# French and UK Stocks Outshine European Peers Ahead of Elections
# French Stocks Boost Europe as Investors Buy the Dip; UK Gains
# Oil Holds Steady Near Two-Month High Amid Falling US Stockpiles
# Sensex @80K: NTPC to Axis Bank—13 stocks outperformed Sensex in H1; Check prices
# Market surge emphasizes importance of Sebi, SAT: CJI DY Chandrachud
# FMCG stocks to recover? D-Street experts peg ‘hold’ for long-term, HUL is ‘buy’
# From HCL Tech to Cummins, Chandan Taparia suggests three stocks to buy today
# Sebi asks stockbrokers to set up mechanism to detect fraud, market abuse
# BSE PSU index shows strong recovery; climbs over 3,600 points since June 4
# Sebi chief Madhabi Buch urges industry to report market misconduct
# 375% Return in 1 Year: Multibagger PSU hits 10% upper circuit; Should you buy?
# Bansal Wire IPO: Here are 10 key things to know from RHP before investing
# Market Strategy for Budget 2024: How should investors position their portfolios?
# Mazagon Dock Shipbuilders' market cap crosses ₹1 lakh crore; stock up 20%
# Top Gainers and Losers today on 4 July, 2024: HCL Technologies, ICICI Bank, HDFC Bank, Bajaj Finance among most active stocks; Check full list here
# Cello World jumps over 6% to new high after launch of ₹730 crore QIP
# Sensex, Nifty 50 end with mild gains on profit booking at higher levels
# Multibagger Shilchar Technologies soars 11550% in 4 years, 577% in last 1 year
# Power sector's meteoric rise faces valuation concerns
# Bandhan Bank share price down almost 2% post Q1 business updates. Buy or Sell?
# Multibagger stock inches closer to lifetime high ahead of Q1 results 2024

# %% [markdown]
# ### Perform sentiment analysis using TextBlob and store in dataframe ###

# %%
data = []


for headline in names:
    blob = TextBlob(headline)
    sentiment_score = blob.sentiment.polarity

    if sentiment_score > 0:
        sentiment = 'positive'
    elif sentiment_score < 0:
        sentiment = 'negative'
    else:
        sentiment = 'neutral'

    data.append({'headline': headline, 'sentiment': sentiment})


df = pd.DataFrame(data)

df
# Out:
#                                               headline sentiment
# 0    Jerome Powell says more good data would streng...  positive
# 1    Budget 2024 | D-Street experts see heightened ...   neutral
# 2    Stocks to buy: Heritage Foods, ONGC, among top...  positive
# 3    Voltas, Blue Star, Havells, others: Strong sum...  positive
# 4    Budget 2024 to focus on capex, Sensex eyes 90K...   neutral
# ..                                                 ...       ...
# 159  Sensex, Nifty 50 end with mild gains on profit...  positive
# 160  Multibagger Shilchar Technologies soars 11550%...   neutral
# 161  Power sector's meteoric rise faces valuation c...   neutral
# 162  Bandhan Bank share price down almost 2% post Q...  negative
# 163  Multibagger stock inches closer to lifetime hi...  positive
#
# [164 rows x 2 columns]
